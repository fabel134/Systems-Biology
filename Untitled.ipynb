# %%
#BITACORA MENSUAL

# %%
#20 de enero
# este dia me dedique a hacer una busqueda de los comandos de linux para poder contestar las dos primeras respuestas resultado en este script 
#27 de enero
#Este lunes lo que hice fui a tomar un curso rapido de python para poder generar mis datos con este lenguaje de programacion
#10 de enero
#intente aprender a crear 'arrays' con python para poder procesar los datos mas eficientemente, pero esto no resulto muy bien.
#17 de febrero
#en equipo tratamos de hacer in script para poder correr todas la respuestas de una vez.

# %%
#!/usr/local/bin/env python3.7
#-*- coding: iso-8859-1 -*-

a = open ('/home/jose/Downloads/biologySistem/ColiNet-1.0/coliInterFullNames.txt' , 'r')

b = open ('/home/jose/Downloads/biologySistem/ColiNet-1.0/coliInterFullVec1.txt' , 'r')

print('¿Cuántos nodos tiene?:')
print(len(a.readlines()))
a.close()

print('¿Cuántos aristas tiene?:')
print(len(b.readlines()))
b.close()

#PREGUNTA TRES. En esta parte solo me quede a la mitad de la respuesta
# Asegura que panda este disponible
import pandas as pd

# lee el archivo **surveys** CSV
c = pd.read_csv ('/home/jose/Downloads/biologySistem/ColiNet-1.0/coliInterFullVec1.txt', sep=' ')


d = c.iloc[:, 0:2]
#print(d)
#d.to_csv('coli.csv') #Este script fue para formatear el archivo original
print(d)
df = pd.DataFrame([d])
#df = pd.read_csv(d)
#print(df)

#df = pd.read_csv('/home/jose/Downloads/biologySistem/coli.csv', delimiter= '\s+', index_col=False)
#df.drop_duplicates(subset=['0','1'])
#df = pd.read_csv('/home/jose/Downloads/biologySistem/coli.csv', sep=',' , header=None , index_col=False)
#print(df)
#print(df.duplicated())

#print(df) #tf = df.drop_duplicates()
#print(tf)
# Out:
# ¿Cuántos nodos tiene?:
# 424
# ¿Cuántos aristas tiene?:
# 578
#       OP  FTN
# 0      3    4
# 1      6    6
# 2     11    6
# 3     14    6
# 4      8    9
# 5    357   15
# 6     17   18
# 7     19   20
# 8     20   20
# 9     21   20
# 10    22   20
# 11    23   20
# 12     1   24
# 13    17   24
# 14    18   24
# 15    49   24
# 16    73   24
# 17    76   24
# 18    85   24
# 19   117   24
# 20   144   24
# 21   152   24
# 22   153   24
# 23   165   24
# 24   172   24
# 25   177   24
# 26   203   24
# 27   218   24
# 28   243   24
# 29   286   24
# ..   ...  ...
# 547   31  414
# 548   32  414
# 549   33  414
# 550   45  414
# 551  221  414
# 552  222  414
# 553  231  414
# 554  254  414
# 555  255  414
# 556  284  414
# 557  300  414
# 558  301  414
# 559  302  414
# 560  311  414
# 561  312  414
# 562  313  414
# 563  352  414
# 564  354  414
# 565  355  414
# 566  372  414
# 567  373  414
# 568  387  414
# 569  403  414
# 570  414  414
# 571  417  416
# 572  422  418
# ...

# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
import numpy as np
import matplotlib.mlab as mlab

FullVec= pd.read_csv('/home/jose/Downloads/biologySistem/ColiNet-1.0/coliInterFullVec1.txt', 'r')

df1 = DataFrame(FullVec, columns = ['OP', 'FTN' , 'NOSE'])
print(df1)
dups_FTN = df1.piv
# Out:
#      OP  FTN  NOSE
# 0   NaN  NaN   NaN
# 1   NaN  NaN   NaN
# 2   NaN  NaN   NaN
# 3   NaN  NaN   NaN
# 4   NaN  NaN   NaN
# 5   NaN  NaN   NaN
# 6   NaN  NaN   NaN
# 7   NaN  NaN   NaN
# 8   NaN  NaN   NaN
# 9   NaN  NaN   NaN
# 10  NaN  NaN   NaN
# 11  NaN  NaN   NaN
# 12  NaN  NaN   NaN
# 13  NaN  NaN   NaN
# 14  NaN  NaN   NaN
# 15  NaN  NaN   NaN
# 16  NaN  NaN   NaN
# 17  NaN  NaN   NaN
# 18  NaN  NaN   NaN
# 19  NaN  NaN   NaN
# 20  NaN  NaN   NaN
# 21  NaN  NaN   NaN
# 22  NaN  NaN   NaN
# 23  NaN  NaN   NaN
# 24  NaN  NaN   NaN
# 25  NaN  NaN   NaN
# 26  NaN  NaN   NaN
# 27  NaN  NaN   NaN
# 28  NaN  NaN   NaN
# 29  NaN  NaN   NaN
# ..   ..  ...   ...
# 547 NaN  NaN   NaN
# 548 NaN  NaN   NaN
# 549 NaN  NaN   NaN
# 550 NaN  NaN   NaN
# 551 NaN  NaN   NaN
# 552 NaN  NaN   NaN
# 553 NaN  NaN   NaN
# 554 NaN  NaN   NaN
# 555 NaN  NaN   NaN
# 556 NaN  NaN   NaN
# 557 NaN  NaN   NaN
# 558 NaN  NaN   NaN
# 559 NaN  NaN   NaN
# 560 NaN  NaN   NaN
# 561 NaN  NaN   NaN
# ...
